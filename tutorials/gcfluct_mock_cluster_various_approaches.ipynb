# %% [markdown]
# # Power spectra of mock cluster observations
#
# ## Last edited by Charles Romero 05 September 2025
#
# Now that we've considered power spectra in an image which is described by some power spectrum, let's consider the actual kind of image (but idealized, of course) that we might encounter.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.ndimage as ndi
import gcfluct.gc.selfsimilar_gc as ssgc
import gcfluct.spectra.spectra2d as spectra
import gcfluct.spectra.gc_spec_deproj as deproj
import gcfluct.utils.image_filtering as imf
import gcfluct.utils.mock_obs as mo
import astropy.units as u

# %% [markdown]
# ### Pick a cluster
#
# Defined by self-similar criteria, i.e. solely z and $M_{500}$.

# %%
z = 0.4
m500 = 5e14 * u.M_sun

# %%
gc_model = ssgc.SS_Model(z,m500)

# %%
#d_ang = ssgc.get_d_ang(z).to("kpc").value
kpc_per_arcsecond = gc_model.d_ang.to("kpc").value / (3600 * 180 / np.pi)
print("kpc per arcsecond: ",kpc_per_arcsecond)
# Out:
# kpc per arcsecond:  5.37273628890832

# %%
gc_model.set_xr_USBP()

# %% [markdown]
# ## Prepare to make a mock cluster image.
#
# We have a radial surface brightness profile in hand, but now we want to add fluctuations to that surface brightness image. To do that, we'll want to make a map with a given power spectrum. In particular, let's choose a plausible (idealized, as always) power spectrum for density (well, emissivity) fluctuations.

# %%
# Define a turbulent (3D) power spectrum. 
# I'm ignoring a dissipative scale; the default will put it at very small scales
# I'll also leave the eta_c and eta_d parameters as their defaults.

kc = 1e-3         # Assume this is in [pixsize]^(-1) -- so kpc^-1 in our case.
slope = -3.7        # Power goes as k**slope
p0 = 1e-4         # Arbitrary units at the moment
no_warn = True    # Ignore some warnings (in regards to pixels for image creation) for now.
ps2img = spectra.ImagesFromPS(slope=slope,kc=kc,p0=p0,no_warn=no_warn)

# %% [markdown]
# ### Let's embark on making images
# 1. We'll want to define some basic image properties (size, pixel size, etc.)
#
# Let's mimic an XMM image.
#
# ESAS typically generates images with 2.5 arcecond pixels (for EPIC cameras).
# For a specific cluster, or rather, a specific redshift, we can consider the pixel size
# either in arcseconds or in kilparsecs. Given that we've defined our power spectrum in
# (inverse) kpc, __we need to specify the pixsize in kpc__.
#
# #### A note on field of view (FOV):
# XMM's EPIC cameras have a ~30' FOV. So the images go out to 15' radially.
# We could try to replicate that in earnest, but we could also trim the image down to 2*R500, radially.

# %%
pix_arcsec = 2.5 # 
pixsize = pix_arcsec*kpc_per_arcsecond    # in kpc
# We set no_warn earlier because the class strongly prefers units to be set.
# It's still "optional" insofar as there are use cases where you don't need to set
# the units
pixunits = u.kpc 
n_r500 = 2
npix = int(np.round(gc_model.arcminutes500*2*n_r500*60/pix_arcsec))   
ps2img.set_image_size(npix,pixsize,pixunits=pixunits)
# Same number as in x -- keep things simple.

# %% [markdown]
# #### Continuing on making images:
#
# 2. Let's generate an image with the input power spectrum and
# 3. Feed that into gc_model, which will enable it to generate a model image for the cluster.

# %%
image = ps2img.generate_realization()
gc_model.set_ss_maps(imagefromps=ps2img) # Let gc_model know the grid used for producing maps.

# %% [markdown]
# You might wonder how I've gone from a 3D power spectrum to a 2D image of it.
# Well, I haven't -- yet.
#
# 4. (Approximately) project the 3D power spectrum image to its 2D counterpart.
#
# We'll do the approximate way to projecting below.

# %%
image_is_sz = False # We are modeling (simulating) an X-ray image, not SZ here.
gc_deproj = deproj.SpecDeproj(gc_model,spec_model=ps2img,sz = image_is_sz) 
n_map = gc_deproj.return_integ_nmap(use_obs_spec=False) # Gives factors to translate between P_2D and P_3D

# %% [markdown]
# Now we have all the pieces to start making a proper model image. In this case, the model images immediately at access that we are considering are X-ray surface brightness images (as count rate images).
#
# 5. Make count rate images.

# %%
ds_s = np.sqrt(n_map.value) * image     # (Model) Normalized residual.
ds = ds_s * gc_model.xrsb_map      # (Model) Residual image in cnts/s/arcmin**2
s_cluster = ds + gc_model.xrsb_map # (Model) image in cnts/s/arcmin**2

# %% [markdown]
# To continue, we need to actually generate count maps -- these are the fundamental X-ray data products.
#
# 6. Make count images
#
# We'll need to adopt some exposure for this. We'll adopt 50 ks below.

# %%
ksec = 1e6 # kiloseconds; 1e5 = a tenth of a Gs = 3 years.
exposure_map = mo.mock_XMM_exposure(ps2img,ksec,rot=30,incChipGaps=True) # in seconds

# %% [markdown]
# Oh, but then we also need to be realistic and add background counts. These can come from particles (a significant source, which ESAS estimates and generates a _bkg image) and other sources. Without separating the exact origin of a remaining background, I'll call  it the "cosmic" background (this isn't exactly correct). From experience, this tends to be of order 1e-3 counts/s/arcmin**2 if not fairly close to that value.
#
# __NB__ I will not try to simulate point sources here, *but* they are also another issue to consider. At the bright end, ESAS (especially via cheese) will identify point sources such that they can be masked. At the faint end, point sources may not be identified and can contribute to contamination. There are ways to account for this (cf Romero et al. 2023).

# %%
s_particle_bkg = 1e-3                  # This is a typical uniform, quiescent particle X-ray background. Soft protons and SWCX usually are sub-dominant.
s_cosmic_bkg = 1e-3                    # The cosmic X-ray background
s_bkg = s_particle_bkg + s_cosmic_bkg  # Total background rate

# %%
s_tot = s_cluster + s_bkg  # Assume that we can account for all photons in this manner
Counts_Total = s_tot * exposure_map * (pix_arcsec/60)**2
Noise_Counts = (gc_model.xrsb_map + s_bkg) * exposure_map * (pix_arcsec/60)**2

# %%
rng = np.random.default_rng()
SyntheticImage = rng.poisson(lam=Counts_Total)

# %%
CntFig = plt.figure(1,figsize=(4,4),dpi=200)
CntAx = CntFig.add_subplot(111)
CntAx.imshow(SyntheticImage,norm="log")
#xlims = CntAx.get_xlim()
#ylims = CntAx.get_ylim()
#CntAx.set_xlim(xlims)
#CntAx.set_ylim(ylims)
    
CntAx.tick_params(top=False, bottom=False, left=False, right=False,
                labelleft=False, labelbottom=False)

# %% [markdown]
# ## Exercise for the reader
#
# Now that you've seen the construction of this image and how to calculate the power spectrum, you should try to compute the power spectrum of the fluctuations from only `SyntheticImage` and `exposure_map`. In principle, ESAS (the XMM processing software) will also produce a background map due to particles. So, rather than a uniform map (taken as a scalar above), `S_particle_bkg` would be a map produced by ESAS (but in counts, with non-negative float values).
#
# ### General steps:
# 1. Fit a surface brightness profile to the data
# 2. Calculate a $\delta S / S$ map
# 3. Calculate "the" power spectrum
#    * Within what region(s)?
# 5. Deproject from the image PS ($P_{2D}$) to the 3-d power spectrum ($P_{3D}$)

# %%
model_cluster_counts = gc_model.xrsb_map * exposure_map * (pix_arcsec/60)**2
# Counts_Total

# %%
def create_mask(exposure,sigma=2,showImage=False):
    expo_ggm = ndi.gaussian_gradient_magnitude(exposure,sigma)
    expo_smo = ndi.gaussian_filter(exposure,sigma)
    expo_rat = exposure / expo_smo
    tomask = (expo_ggm > 0.5*np.max(expo_ggm)) + (expo_rat > 1.05) + (exposure < 0.5*np.median(exposure))
    mymask = np.ones(exposure.shape)
    mymask[tomask] = 0
    if showImage:
        MaskFig = plt.figure(2,figsize=(4,4),dpi=200)
        MaskFig.clf()
        MaskAx = MaskFig.add_subplot(111)
        MaskAx.imshow(mymask,vmin=0,vmax=1)   
        MaskAx.tick_params(top=False, bottom=False, left=False, right=False,
                        labelleft=False, labelbottom=False)

    return mymask

def alla_Eckert(img2ps_obj,cnts,model,exposure,pixArea,addMask=None,RMS=False,useModel=False,msk_bin=1):

    mask_by_bin = img2ps_obj.mask_by_bin
    myinds = (mask_by_bin == msk_bin)
    mymask = np.zeros(model.shape)
    mymask[myinds] = 1
    if addMask is None:
        if useModel:
            mean_sb = np.sqrt(np.mean(model**2)) if RMS else np.mean(model)
        else:
            mean_sb = np.sqrt(np.mean(cnts**2)) if RMS else np.mean(cnts)
        expo_sq = np.mean(exposure**2)
    else:
        total_mask = addMask*mymask
        if useModel:
            if RMS:
                mean_sb = np.sqrt(np.sum( (model*total_mask)**2) /np.sum(total_mask**2)) 
            else:
                mean_sb = np.sum(model*total_mask) / np.sum(total_mask)
        else:
            if RMS:
                mean_sb = np.sqrt(np.sum( (cnts*total_mask)**2) /np.sum(total_mask**2)) 
            else:
                mean_sb = np.sum(cnts*total_mask) / np.sum(total_mask)
                
        expo_sq = np.sum( (exposure*total_mask)**2 ) / np.sum(total_mask)

    mean_sb *= pixArea
    Rescaled = cnts / (mean_sb * np.sqrt(expo_sq))

    img2ps_obj.update_img(Rescaled)
    img2ps_obj.ps_via_a12_2d()

    return mean_sb, expo_sq

# %%
myMask = create_mask(exposure_map,showImage=False) # Finds chip gaps...roughly
annuli = np.array([0.05, 1.0])*gc_model.r500.value  # Will take an annulus (circle) with 0 <= r < R500.
annulus1 = np.array([0.05, 0.19])*gc_model.r500.value  # Will take an annulus (circle) with 0 <= r < R500.
annulus2 = np.array([0.19, 0.46])*gc_model.r500.value  # Will take an annulus (circle) with 0 <= r < R500.
annulus3 = np.array([0.46, 1.0])*gc_model.r500.value  # Will take an annulus (circle) with 0 <= r < R500.

r500_mask = np.ones(ps2img.rmat.shape)
omit = (ps2img.rmat > gc_model.r500.value)  # r500 will is in kpc already.
r500_mask[omit] = 0

FullMask = r500_mask*myMask

n_avg = np.sum(n_map.value * FullMask) / np.sum(FullMask)

# %%
n_annulus = np.zeros(3)
for ai,annulus in enumerate([annulus1,annulus2,annulus3]):
    my_mask = np.zeros(FullMask.shape)
    my_inc = (ps2img.rmat > annulus[0])*(ps2img.rmat <= annulus[1])
    my_mask[my_inc] = 1
    n_annulus[ai] = np.sum(n_map.value * my_mask * myMask) / np.sum(my_mask * myMask)
    print(n_annulus[ai], n_avg)
# Out:
# 0.005227070819679927 0.0016601932175168285
# 0.002544254319015903 0.0016601932175168285
# 0.0011809848224509408 0.0016601932175168285

# %%
Eckert_case1 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Eckert_case1.set_annular_mask_by_bin(annuli)
Eckert_case1.set_wave_numbers()  # Omit option inputs -> use defaults

Eckert_case2 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Eckert_case2.set_annular_mask_by_bin(annulus1)
Eckert_case2.set_wave_numbers()  # Omit option inputs -> use defaults

Eckert_case3 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Eckert_case3.set_annular_mask_by_bin(annulus2)
Eckert_case3.set_wave_numbers()  # Omit option inputs -> use defaults

Eckert_case4 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Eckert_case4.set_annular_mask_by_bin(annulus3)
Eckert_case4.set_wave_numbers()  # Omit option inputs -> use defaults

Eckert_case5 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Eckert_case5.set_annular_mask_by_bin(annuli)
Eckert_case5.set_wave_numbers()  # Omit option inputs -> use defaults

Romero_case1 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Romero_case1.set_annular_mask_by_bin(annuli)
Romero_case1.set_wave_numbers()  # Omit option inputs -> use defaults
Romero_noise = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Romero_noise.set_annular_mask_by_bin(annuli)
Romero_noise.set_wave_numbers()  # Omit option inputs -> use defaults

Romero_case2 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Romero_case2.set_annular_mask_by_bin(annulus1)
Romero_case2.set_wave_numbers()  # Omit option inputs -> use defaults
Romero_noise2 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Romero_noise2.set_annular_mask_by_bin(annulus1)
Romero_noise2.set_wave_numbers()  # Omit option inputs -> use defaults

Romero_case3 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Romero_case3.set_annular_mask_by_bin(annulus2)
Romero_case3.set_wave_numbers()  # Omit option inputs -> use defaults
Romero_noise3 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Romero_noise3.set_annular_mask_by_bin(annulus2)
Romero_noise3.set_wave_numbers()  # Omit option inputs -> use defaults

Romero_case4 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Romero_case4.set_annular_mask_by_bin(annulus3)
Romero_case4.set_wave_numbers()  # Omit option inputs -> use defaults
Romero_noise4 = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Romero_noise4.set_annular_mask_by_bin(annulus3)
Romero_noise4.set_wave_numbers()  # Omit option inputs -> use defaults
fft_obj = spectra.PSfromImages(image * np.sqrt(n_avg), pixsize=pixsize, pixunits=pixunits, intrinsic_mask = None)
fft_obj.ps_via_fft_2d()

# %%
Eckert_case1_N = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Eckert_case1_N.set_annular_mask_by_bin(annuli)
Eckert_case1_N.set_wave_numbers()  # Omit option inputs -> use defaults

Eckert_case2_N = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Eckert_case2_N.set_annular_mask_by_bin(annulus1)
Eckert_case2_N.set_wave_numbers()  # Omit option inputs -> use defaults

Eckert_case3_N = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Eckert_case3_N.set_annular_mask_by_bin(annulus2)
Eckert_case3_N.set_wave_numbers()  # Omit option inputs -> use defaults

Eckert_case4_N = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Eckert_case4_N.set_annular_mask_by_bin(annulus3)
Eckert_case4_N.set_wave_numbers()  # Omit option inputs -> use defaults

Eckert_case5_N = spectra.PSfromImages(SyntheticImage, pixsize=pixsize, pixunits=pixunits, intrinsic_mask = FullMask)
Eckert_case5_N.set_annular_mask_by_bin(annuli)
Eckert_case5_N.set_wave_numbers()  # Omit option inputs -> use defaults

# %%
nIters = 50
pixArea = (pix_arcsec/60)**2
redoAll = True
useSN = True
useRMS = True

for i in range(nIters):

    if redoAll:
        image = ps2img.generate_realization()
        ds_s = np.sqrt(n_map.value) * image     # (Model) Normalized residual.
        ds = ds_s * gc_model.xrsb_map      # (Model) Residual image in cnts/s/arcmin**2
        s_cluster = ds + gc_model.xrsb_map # (Model) image in cnts/s/arcmin**2
        s_tot = s_cluster + s_bkg  # Assume that we can account for all photons in this manner
        Counts_Total = s_tot * exposure_map * (pix_arcsec/60)**2
    SyntheticImage = rng.poisson(lam=Counts_Total)
    SyntheticNoise = rng.poisson(lam=Noise_Counts)
    Cnts4Noise = SyntheticNoise if useSN else SyntheticImage

    residual = SyntheticImage - model_cluster_counts
    norm_resid = residual / exposure_map / (pix_arcsec/60)**2 / gc_model.xrsb_map # cnt rates...
    badind = np.isnan(norm_resid)
    norm_resid[badind] = 0.0

    # Case 1: Take Eckert+ 2017 in the most literal sense.
    u_s1, sumE1 = alla_Eckert(Eckert_case1, residual, gc_model.xrsb_map, exposure_map, pixArea, addMask=FullMask,RMS=useRMS,useModel=True)
    noise_case1 = np.sum(Cnts4Noise*FullMask) / (u_s1**2 * sumE1) * pixsize**2 / np.sum(FullMask)
    u_s1N, sumE1N = alla_Eckert(Eckert_case1_N, SyntheticNoise- model_cluster_counts,gc_model.xrsb_map, exposure_map, pixArea, addMask=FullMask,RMS=useRMS,useModel=True)

    # Case 2: Assume Eckert+ 2017 wants to calculate PS on the *residual* image.
    u_s2, sumE2 = alla_Eckert(Eckert_case2, residual, gc_model.xrsb_map,exposure_map, pixArea, addMask=FullMask,RMS=useRMS,useModel=True)
    noise_case2 = np.sum(Cnts4Noise*FullMask) / (u_s2**2 * sumE2) * pixsize**2 / np.sum(FullMask)
    u_s2N, sumE2N = alla_Eckert(Eckert_case2_N, SyntheticNoise - model_cluster_counts,gc_model.xrsb_map, exposure_map, pixArea, addMask=FullMask,RMS=useRMS,useModel=True)

    # Case 3: Assume Eckert+ 2017 wants to calculate PS on the *residual* image.
    u_s3, sumE3 = alla_Eckert(Eckert_case3, residual, gc_model.xrsb_map, exposure_map, pixArea, addMask=FullMask,RMS=useRMS,useModel=True)
    noise_case3 = np.sum(Cnts4Noise*FullMask) / (u_s3**2 * sumE3) * pixsize**2 / np.sum(FullMask)
    u_s3N, sumE3N = alla_Eckert(Eckert_case3_N, SyntheticNoise - model_cluster_counts,gc_model.xrsb_map, exposure_map, pixArea, addMask=FullMask,RMS=useRMS,useModel=True)

    # Case 4: Assume Eckert+ 2017 wants to calculate PS on the *residual* image; calculating on masked areas.
    u_s4, sumE4 = alla_Eckert(Eckert_case4, residual, gc_model.xrsb_map, exposure_map, pixArea, addMask=FullMask,RMS=useRMS,useModel=True)
    noise_case4 = np.sum(Cnts4Noise*FullMask) / (u_s4**2 * sumE4) * pixsize**2 / np.sum(FullMask)
    u_s4N, sumE4N = alla_Eckert(Eckert_case4_N, SyntheticNoise - model_cluster_counts,gc_model.xrsb_map, exposure_map, pixArea, addMask=FullMask,RMS=useRMS,useModel=True)
    # Factor of pi in the noise calculation? I think not.

    # Case 5: Assume Eckert+ 2017 wants to calculate PS on the *residual* image; calculating on masked areas.
    ones = np.ones(exposure_map.shape)
    u_s5, sumE5 = alla_Eckert(Eckert_case5, norm_resid, ones, ones, 1.0, addMask=FullMask, RMS=useRMS)
    noise_case5 = np.sum(SyntheticImage*FullMask) / (u_s4**2 * sumE4) * pixsize**2 / np.sum(FullMask) # Leave u_s4
    norm_noise = (SyntheticNoise - model_cluster_counts) / exposure_map / (pix_arcsec/60)**2 / gc_model.xrsb_map # cnt rates...
    u_s5N, sumE5N = alla_Eckert(Eckert_case5_N, norm_noise, ones, ones, 1.0, addMask=FullMask, RMS=useRMS)

    #print(Eckert_case1.a12_pk[3,0], Eckert_case2.a12_pk[3,0], Eckert_case3.a12_pk[3,0],
    #      Eckert_case4.a12_pk[3,0], Eckert_case5.a12_pk[3,0])
    #print(sumE1,sumE2,sumE3,sumE4,sumE5)
    #print("Number of bad indices: ",np.sum(badind))
    #print("=========================================================================")
    #print(noise_case1, noise_case2, noise_case3, noise_case4, noise_case5)
    #print("-------------------------------------------------------------------------")
    
    # Case 6: How I do it.
    Romero_case1.update_img(norm_resid)
    Romero_case1.ps_via_a12_2d()
    resid_noise = (SyntheticNoise / exposure_map / (pix_arcsec/60)**2) - gc_model.xrsb_map 
    norm_noise = resid_noise / gc_model.xrsb_map 
    bnnind = np.isnan(norm_noise)
    norm_noise[bnnind] = 0.0
    Romero_noise.update_img(norm_noise)
    Romero_noise.ps_via_a12_2d()

    Romero_case2.update_img(norm_resid)
    Romero_case2.ps_via_a12_2d()
    Romero_noise2.update_img(norm_noise)
    Romero_noise2.ps_via_a12_2d()

    Romero_case3.update_img(norm_resid)
    Romero_case3.ps_via_a12_2d()
    Romero_noise3.update_img(norm_noise)
    Romero_noise3.ps_via_a12_2d()

    Romero_case4.update_img(norm_resid)
    Romero_case4.ps_via_a12_2d()
    Romero_noise4.update_img(norm_noise)
    Romero_noise4.ps_via_a12_2d()

    if i == 0:
        #pk_case1 = Eckert_case1.a12_pk - np.ones(Eckert_case1.a12_pk.shape)*noise_case1
        #pk_case2 = Eckert_case2.a12_pk - np.ones(Eckert_case2.a12_pk.shape)*noise_case2
        #pk_case3 = Eckert_case3.a12_pk - np.ones(Eckert_case3.a12_pk.shape)*noise_case3
        #pk_case4 = Eckert_case4.a12_pk - np.ones(Eckert_case4.a12_pk.shape)*noise_case4
        #pk_case5 = Eckert_case5.a12_pk - np.ones(Eckert_case5.a12_pk.shape)*noise_case5

        pk_case1 = Eckert_case1.a12_pk - Eckert_case1_N.a12_pk
        pk_case2 = Eckert_case2.a12_pk - Eckert_case2_N.a12_pk
        pk_case3 = Eckert_case3.a12_pk - Eckert_case3_N.a12_pk
        pk_case4 = Eckert_case4.a12_pk - Eckert_case4_N.a12_pk
        pk_case5 = Eckert_case5.a12_pk - Eckert_case5_N.a12_pk
        
        pk_case6 = Romero_case1.a12_pk - Romero_noise.a12_pk
        pk_case7 = Romero_case2.a12_pk - Romero_noise2.a12_pk
        pk_case8 = Romero_case3.a12_pk - Romero_noise3.a12_pk
        pk_case9 = Romero_case4.a12_pk - Romero_noise4.a12_pk
        pk_case1 = np.expand_dims(pk_case1,axis=-2)
        pk_case2 = np.expand_dims(pk_case2,axis=-2)
        pk_case3 = np.expand_dims(pk_case3,axis=-2)
        pk_case4 = np.expand_dims(pk_case4,axis=-2)
        pk_case5 = np.expand_dims(pk_case5,axis=-2)
        pk_case6 = np.expand_dims(pk_case6,axis=-2)
        pk_case7 = np.expand_dims(pk_case7,axis=-2)
        pk_case8 = np.expand_dims(pk_case8,axis=-2)
        pk_case9 = np.expand_dims(pk_case9,axis=-2)
    else:
        #pk_case1_tmp = Eckert_case1.a12_pk - np.ones(Eckert_case1.a12_pk.shape)*noise_case1
        #pk_case2_tmp = Eckert_case2.a12_pk - np.ones(Eckert_case2.a12_pk.shape)*noise_case2
        #pk_case3_tmp = Eckert_case3.a12_pk - np.ones(Eckert_case3.a12_pk.shape)*noise_case3
        #pk_case4_tmp = Eckert_case4.a12_pk - np.ones(Eckert_case4.a12_pk.shape)*noise_case4
        #pk_case5_tmp = Eckert_case5.a12_pk - np.ones(Eckert_case5.a12_pk.shape)*noise_case5

        pk_case1_tmp = Eckert_case1.a12_pk - Eckert_case1_N.a12_pk
        pk_case2_tmp = Eckert_case2.a12_pk - Eckert_case2_N.a12_pk
        pk_case3_tmp = Eckert_case3.a12_pk - Eckert_case3_N.a12_pk
        pk_case4_tmp = Eckert_case4.a12_pk - Eckert_case4_N.a12_pk
        pk_case5_tmp = Eckert_case5.a12_pk - Eckert_case5_N.a12_pk
        
        pk_case6_tmp = Romero_case1.a12_pk - Romero_noise.a12_pk
        pk_case7_tmp = Romero_case2.a12_pk - Romero_noise2.a12_pk
        pk_case8_tmp = Romero_case3.a12_pk - Romero_noise3.a12_pk
        pk_case9_tmp = Romero_case4.a12_pk - Romero_noise4.a12_pk

        pk_case1_tmp = np.expand_dims(pk_case1_tmp,axis=-1)
        pk_case2_tmp = np.expand_dims(pk_case2_tmp,axis=-1)
        pk_case3_tmp = np.expand_dims(pk_case3_tmp,axis=-1)
        pk_case4_tmp = np.expand_dims(pk_case4_tmp,axis=-1)
        pk_case5_tmp = np.expand_dims(pk_case5_tmp,axis=-1)
        pk_case6_tmp = np.expand_dims(pk_case6_tmp,axis=-1)
        pk_case7_tmp = np.expand_dims(pk_case7_tmp,axis=-1)
        pk_case8_tmp = np.expand_dims(pk_case8_tmp,axis=-1)
        pk_case9_tmp = np.expand_dims(pk_case9_tmp,axis=-1)

        pk_case1 = np.hstack([pk_case1, pk_case1_tmp])
        pk_case2 = np.hstack([pk_case2, pk_case2_tmp])
        pk_case3 = np.hstack([pk_case3, pk_case3_tmp])
        pk_case4 = np.hstack([pk_case4, pk_case4_tmp])
        pk_case5 = np.hstack([pk_case5, pk_case5_tmp])
        pk_case6 = np.hstack([pk_case6, pk_case6_tmp])
        pk_case7 = np.hstack([pk_case7, pk_case7_tmp])        
        pk_case8 = np.hstack([pk_case8, pk_case8_tmp])
        pk_case9 = np.hstack([pk_case9, pk_case9_tmp])
# Out:
# /tmp/ipykernel_167320/1077003303.py:21: RuntimeWarning: invalid value encountered in divide
#   norm_resid = residual / exposure_map / (pix_arcsec/60)**2 / gc_model.xrsb_map # cnt rates...
# /tmp/ipykernel_167320/1077003303.py:50: RuntimeWarning: invalid value encountered in divide
#   norm_noise = (SyntheticNoise - model_cluster_counts) / exposure_map / (pix_arcsec/60)**2 / gc_model.xrsb_map # cnt rates...
# /tmp/ipykernel_167320/1077003303.py:64: RuntimeWarning: invalid value encountered in divide
#   resid_noise = (SyntheticNoise / exposure_map / (pix_arcsec/60)**2) - gc_model.xrsb_map

# %%
pk_case1_rms = np.std(pk_case1, axis=1)
pk_case2_rms = np.std(pk_case2, axis=1)
pk_case3_rms = np.std(pk_case3, axis=1)
pk_case4_rms = np.std(pk_case4, axis=1)
pk_case5_rms = np.std(pk_case5, axis=1)
pk_case6_rms = np.std(pk_case6, axis=1)
pk_case7_rms = np.std(pk_case7, axis=1)
pk_case8_rms = np.std(pk_case8, axis=1)
pk_case9_rms = np.std(pk_case9, axis=1)

pk_case1_mean = np.mean(pk_case1, axis=1)
pk_case2_mean = np.mean(pk_case2, axis=1)
pk_case3_mean = np.mean(pk_case3, axis=1)
pk_case4_mean = np.mean(pk_case4, axis=1)
pk_case5_mean = np.mean(pk_case5, axis=1)
pk_case6_mean = np.mean(pk_case6, axis=1)
pk_case7_mean = np.mean(pk_case7, axis=1)
pk_case8_mean = np.mean(pk_case8, axis=1)
pk_case9_mean = np.mean(pk_case9, axis=1)

# %%
print(pk_case1.shape,pk_case1_rms.shape)
# Out:
# (6, 50, 1) (6, 1)

# %%
print(u_s1, u_s2, u_s3, u_s4)
# Out:
# 1.3913208860962137e-06 7.859546209726329e-07 9.760671284007296e-07 1.5147014613423836e-06

# %%
def plot_amp_spec(ax, kvals, ymean, yrms, label=None, prnt = False, offsets=True, nval=None, **kwargs):

    for ri,(pk_ev,pk_unc) in enumerate(zip(ymean.T,yrms.T)):
        if prnt:
            print(pk_ev)
            print("==========================================================")
        if nval is None:
            amp_spec = np.sqrt( pk_ev * 2 * np.pi * kvals**2)
            amp_unc = np.sqrt( pk_unc * 2 * np.pi * kvals**2) / 2
            binstr = "; bin {:d}; 2D".format(ri+1)
        else:
            amp_spec = np.sqrt( pk_ev * 4 * np.pi * kvals**3 / nval)
            amp_unc = np.sqrt( pk_unc * 4 * np.pi * kvals**3 / nval) / 2
            binstr = "; bin {:d}; 3D".format(ri+1)
            
        if offsets:
            myoff = rng.normal(loc=1,scale=0.03)
        else:
            myoff = 1.0
        ax.errorbar(myoff*kvals, amp_spec, yerr=amp_unc, label=label+binstr, **kwargs)

# %%
myfig = plt.figure(2,figsize=(5,4),dpi=200)
myfig.clf()
myax = myfig.add_subplot(111)

TheoryKs = np.logspace(np.log10(np.min(Eckert_case1.a12_kn)),np.log10(np.max(Eckert_case1.a12_kn)),100)
pk_model = np.expand_dims(ps2img.get_parameterized_ps(TheoryKs) * n_avg, axis=-1)
print(pk_model.shape)
#import pdb;pdb.set_trace()
pk_model_rms = pk_model/1e20
plot_amp_spec(myax, TheoryKs, pk_model, pk_model_rms, label ='Input spectrum', prnt=True)
#plot_amp_spec(myax, fft_obj.fft_kb, np.expand_dims(fft_obj.fft_pk,axis=-1), 
#              np.expand_dims(fft_obj.fft_pk,axis=-1)/1e6, label ='Input spectrum, realization', prnt=True)
plot_amp_spec(myax, Eckert_case1.a12_kn, pk_case1_mean, pk_case1_rms, label ='5-100', prnt=True, color="C1")
plot_amp_spec(myax, Eckert_case1.a12_kn, pk_case1_mean, pk_case1_rms, label ='5-100', prnt=True, color="C1",
             ls="--", nval=n_avg)
plot_amp_spec(myax, Eckert_case1.a12_kn, pk_case2_mean, pk_case2_rms, label ='5-19; 2D', prnt=True, color="C2")
plot_amp_spec(myax, Eckert_case1.a12_kn, pk_case2_mean, pk_case2_rms, label ='5-19; 3D', prnt=True, color="C2",
              ls="--",nval=n_annulus[0])
plot_amp_spec(myax, Eckert_case1.a12_kn, pk_case3_mean, pk_case3_rms, label ='19-46', prnt=True, color="C3")
plot_amp_spec(myax, Eckert_case1.a12_kn, pk_case3_mean, pk_case3_rms, label ='19-46', prnt=True, color="C3",
             ls="--", nval=n_annulus[1])
plot_amp_spec(myax, Eckert_case1.a12_kn, pk_case4_mean, pk_case4_rms, label ='46-100', prnt=True, color="C4")
plot_amp_spec(myax, Eckert_case1.a12_kn, pk_case4_mean, pk_case4_rms, label ='46-100', prnt=True, color="C4",
             ls="--", nval=n_annulus[2])
#plot_amp_spec(myax, Eckert_case1.a12_kn, pk_case5_mean, pk_case5_rms, label ='Eckert, norm resid', prnt=True)
#plot_amp_spec(myax, Eckert_case1.a12_kn, pk_case6_mean, pk_case6_rms, label ='Romero methodology', prnt=True)

myax.set_xlabel(r"k (kpc$^{-1}$")
myax.set_ylabel(r"A$(k)$")
myax.legend()
myax.set_xscale("log")
myax.set_yscale("log")
myax.set_title("Amplitude Spectra of Mock SZ")
myfig.tight_layout()
outdir = "/home/data/Synthetic/gcfluct/Testing_November/"
myfig.savefig(outdir+"AmplitudeSpectra_6methods_06Nov2025_LowNoise_v0.png")
# Out:
# (100, 1)
# [1.37058381e-03 2.03276625e-02 1.98149388e-01 1.35057042e+00
#  6.78559759e+00 2.62875123e+01 8.15946572e+01 2.09665422e+02
#  4.58618107e+02 8.74490223e+02 1.48332186e+03 2.27715047e+03
#  3.21082498e+03 4.21075054e+03 5.19117522e+03 6.07148658e+03
#  6.78927109e+03 7.30680503e+03 7.61133886e+03 7.71107163e+03
#  7.62905944e+03 7.39689193e+03 7.04928054e+03 6.62005622e+03
#  6.13961475e+03 5.63359267e+03 5.12246003e+03 4.62171907e+03
#  4.14245049e+03 3.69201609e+03 3.27479005e+03 2.89284266e+03
#  2.54653745e+03 2.23502782e+03 1.95665433e+03 1.70925221e+03
#  1.49038213e+03 1.29749798e+03 1.12806469e+03 9.79637553e+02
#  8.49912307e+02 7.36753928e+02 6.38210026e+02 5.52513548e+02
#  4.78078292e+02 4.13489835e+02 3.57493746e+02 3.08982435e+02
#  2.66981560e+02 2.30636621e+02 1.99200130e+02 1.72019609e+02
#  1.48526538e+02 1.28226298e+02 1.10689117e+02 9.55419700e+01
#  8.24613793e+01 7.11670531e+01 6.14162775e+01 5.29989956e+01
# ...

# %%
print( (2.5e5)**2 )
# Out:
# 62500000000.0
